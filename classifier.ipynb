# %%
#!pip3 install mne pandas sklearn matplotlib seaborn
from EEGRecording import EEGRecording
from utils import visualize
from Pipeline import Pipeline

from pathlib import Path
import numpy as np

# %%
# visualize(dir / 'raw_data/asd/A101_raw_512Hz.asc', 512)
dir = Path('.')  # directory for eeg_asd data

visualize(dir / 'data_raw/asd/A100_raw_256Hz.asc', 256)

# 60 hz = line noise....... (power outlet)

# manual inspection.. remove channels that are vertically shifted from other channels...
# Out:
# Creating RawArray with float64 data, n_channels=34, n_times=25314
#     Range : 0 ... 25313 =      0.000 ...    98.879 secs
# Ready.
# Effective window size : 8.000 (s)
# /home/russ/proj/eeg_asd/utils.py:27: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   mne.viz.plot_raw_psd(raw, fmin=0,fmax=30)

# %%
# Visualize the pipeline.... see if anything 
pipeline = Pipeline()
pipeline.load_data()
pipeline.find_common_chanels()
pipeline.save_state('step3')
pipeline.split_into_epochs()
pipeline.do_welch_powerband()
# pipeline.access_point(0,0,0,0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-933df07aae95> in <module>
#       6 pipeline.split_into_epochs()
#       7 pipeline.do_welch_powerband()
# ----> 8 pipeline.access_point(0,0,0,0)
#
# ~/proj/eeg_asd/Pipeline.py in access_point(self, recording_number, epoch_number, chanel_number, band_number)
#     161     # print(f"recoridng #{recording_number}, epoch #{epoch_number}, channel #{chanel_number}, band #{band_number} "f" has a value of {}")
#     162     def access_point(self, recording_number=0, epoch_number=0, chanel_number=0, band_number=0):
# --> 163         return self.pipeline[recording_number].data[epoch_number][chanel_number][band_number]
#     164
#     165     # Spectrogram...
#
# IndexError: list index out of range

# %%
pipeline

# %%
# How to load the data
x = np.load(dir/'data/step3.npy', allow_pickle=True)
print(len(x)) # Should be # of included recordings
print(np.array(x[0].data).shape) # Should be (#Epochs, #Channels, #Bands)

# 25
# (4,34,4)
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-99656ffbe612> in <module>
#       2 x = np.load(dir/'data/step3.npy', allow_pickle=True)
#       3 print(len(x)) # Should be # of included recordings
# ----> 4 print(np.array(x[0].data).shape) # Should be (#Epochs, #Channels, #Bands)
#       5
#       6 # 25
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
